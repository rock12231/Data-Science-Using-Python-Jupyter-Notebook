# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
c = pd.Series(('A','V','I','N','A','S','H'))

# %%
c
# Out:
# 0    A
# 1    V
# 2    I
# 3    N
# 4    A
# 5    S
# 6    H
# dtype: object

# %%
num = pd.Series([2,34,5,6,6,7,8,8,8])
print(num)
print(type(num))
# Out:
# 0     2
# 1    34
# 2     5
# 3     6
# 4     6
# 5     7
# 6     8
# 7     8
# 8     8
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
date = pd.date_range(start = '01-01-2020', end = '20-01-2020')
print(date)
print(type(date))
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#                '2020-01-13', '2020-01-14', '2020-01-15', '2020-01-16',
#                '2020-01-17', '2020-01-18', '2020-01-19', '2020-01-20'],
#               dtype='datetime64[ns]', freq='D')
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
print(num[2])
# Out:
# 5

# %%
print(c[2])
# Out:
# I

# %%
print(c[1:4])
# Out:
# 1    V
# 2    I
# 3    N
# dtype: object

# %%
help(pd.date_range(start='01-01-2021', end='02-01-2020'))
# Out:
# Help on DatetimeIndex in module pandas.core.indexes.datetimes object:
#
# class DatetimeIndex(pandas.core.indexes.datetimelike.DatetimeTimedeltaMixin, DatetimeDelegateMixin)
#  |  DatetimeIndex(data=None, freq=None, tz=None, normalize=False, closed=None, ambiguous='raise', dayfirst=False, yearfirst=False, dtype=None, copy=False, name=None)
#  |
#  |  Immutable ndarray of datetime64 data, represented internally as int64, and
#  |  which can be boxed to Timestamp objects that are subclasses of datetime and
#  |  carry metadata such as frequency information.
#  |
#  |  Parameters
#  |  ----------
#  |  data : array-like (1-dimensional), optional
#  |      Optional datetime-like data to construct index with.
#  |  copy : bool
#  |      Make a copy of input ndarray.
#  |  freq : str or pandas offset object, optional
#  |      One of pandas date offset strings or corresponding objects. The string
#  |      'infer' can be passed in order to set the frequency of the index as the
# ...

# %%
num = pd.Series([2,4,5,6,6], index= ['a','b','c','d','e'])
print(num)
# Out:
# a    2
# b    4
# c    5
# d    6
# e    6
# dtype: int64

# %%
import numpy as np
se = pd.Series(np.array(range(0,5))+2, index = range(0,5))
print(se)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# 4    6
# dtype: int32

# %% [markdown]
# # Dataframe

# %%
d_df = pd.DataFrame({'FRUITS': ['BANANA','GUAVA','ORANGE','APPLE','KIWI'],
                  'WEIGHT':[12,1,24,2,8],
                  'COLOR':['Yello','Green','Pale yellow','Red','Brrown']})
d_df
# Out:
#    FRUITS  WEIGHT        COLOR
# 0  BANANA      12        Yello
# 1   GUAVA       1        Green
# 2  ORANGE      24  Pale yellow
# 3   APPLE       2          Red
# 4    KIWI       8       Brrown

# %%
yo = pd.read_csv("C:/Users/avina/Desktop/Diamonds.csv")
yo
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
yo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
yo.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
yo.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
yo.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
yo.shape
# Out:
# (53940, 10)

# %%
yo.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
yo.values
# Out:
# array([[0.23, 'Ideal', 'E', ..., 3.95, 3.98, 2.43],
#        [0.21, 'Premium', 'E', ..., 3.89, 3.84, 2.31],
#        [0.23, 'Good', 'E', ..., 4.05, 4.07, 2.31],
#        ...,
#        [0.7, 'Very Good', 'D', ..., 5.66, 5.68, 3.56],
#        [0.86, 'Premium', 'H', ..., 6.15, 6.12, 3.74],
#        [0.75, 'Ideal', 'D', ..., 5.83, 5.87, 3.64]], dtype=object)

# %%
yo.set_index('cut', inplace = True)
yo.head()
# Out:
#          carat color clarity  depth  table  price     x     y     z
# cut
# Ideal     0.23     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# Premium   0.21     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# Good      0.23     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# Premium   0.29     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# Good      0.31     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
yo
# Out:
#            carat color clarity  depth  table  price     x     y     z
# cut
# Ideal       0.23     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# Premium     0.21     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# Good        0.23     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# Premium     0.29     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# Good        0.31     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...          ...   ...     ...    ...    ...    ...   ...   ...   ...
# Ideal       0.72     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# Good        0.72     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# Very Good   0.70     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# Premium     0.86     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# Ideal       0.75     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 9 columns]
