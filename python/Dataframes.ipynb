# %% [markdown]
# #  Dataframes

# %% [markdown]
# ### CRISP DM Framework : "Cross indrestry stander proceser" similer SDLC

# %% [markdown]
# ##### pd.merge()

# %% [markdown]
# ##### pd.cancontenet

# %%
import pandas as pd
import numpy as np

# %%
r1_df = pd.read_csv("C:/Users/avina/Desktop/csv/r1.csv")

# %%
r2_df = pd.read_csv("C:/Users/avina/Desktop/csv/r2.csv")

# %%
an_df = pd.read_csv("C:/Users/avina/Desktop/csv/an.csv")

# %%
r1_df.head()
# Out:
#                               Region               Country  Item Type  \
# 0  Central America and the Caribbean  Antigua and Barbuda   Baby Food
# 1  Central America and the Caribbean                Panama     Snacks
# 2                             Europe        Czech Republic  Beverages
# 3                               Asia           North Korea     Cereal
# 4                               Asia             Sri Lanka     Snacks
#
#   Sales Channel Order Priority  Order Date   Order ID  Ship Date  Units Sold  \
# 0        Online              M  12/20/2013  957081544  1/11/2014         552
# 1       Offline              C    7/5/2010  301644504  7/26/2010        2167
# 2       Offline              C   9/12/2011  478051030  9/29/2011        4778
# 3       Offline              L   5/13/2010  892599952  6/15/2010        9016
# 4       Offline              C   7/20/2015  571902596  7/27/2015        7542
#
#    Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# ...

# %%
r2_df.head()
# Out:
#                          Region Country   Item Type Sales Channel  \
# 0  Middle East and North Africa   Libya   Cosmetics       Offline
# 1                 North America  Canada  Vegetables        Online
# 2  Middle East and North Africa   Libya   Baby Food       Offline
# 3                          Asia   Japan      Cereal       Offline
# 4            Sub-Saharan Africa    Chad      Fruits       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              M  10/18/2014  686800706  10/31/2014        8446      437.20
# 1              M   11/7/2011  185941302   12/8/2011        3018      154.06
# 2              C  10/31/2016  246222341   12/9/2016        1517      255.28
# 3              C   4/10/2010  161442649   5/12/2010        3322      205.70
# 4              H   8/16/2011  645713555   8/31/2011        9845        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0     263.33     3692591.20  2224085.18    1468506.02
# ...

# %%
an_df.head()
# Out:
#    year industry_code_ANZSIC               industry_name_ANZSIC rme_size_grp  \
# 0  2011                    A  Agriculture, Forestry and Fishing          a_0
# 1  2011                    A  Agriculture, Forestry and Fishing          a_0
# 2  2011                    A  Agriculture, Forestry and Fishing          a_0
# 3  2011                    A  Agriculture, Forestry and Fishing          a_0
# 4  2011                    A  Agriculture, Forestry and Fishing          a_0
#
#                                           variable  value               unit
# 0                                    Activity unit  46134              COUNT
# 1                           Rolling mean employees      0              COUNT
# 2                          Salaries and wages paid    279  DOLLARS(millions)
# 3  Sales, government funding, grants and subsidies   8187  DOLLARS(millions)
# 4                                     Total income   8866  DOLLARS(millions)

# %%
new_df = pd.merge(r1_df,r2_df, how='inner',on='Order ID')
new_df
# Out:
# Empty DataFrame
# Columns: [Region_x, Country_x, Item Type_x, Sales Channel_x, Order Priority_x, Order Date_x, Order ID, Ship Date_x, Units Sold_x, Unit Price_x, Unit Cost_x, Total Revenue_x, Total Cost_x, Total Profit_x, Region_y, Country_y, Item Type_y, Sales Channel_y, Order Priority_y, Order Date_y, Ship Date_y, Units Sold_y, Unit Price_y, Unit Cost_y, Total Revenue_y, Total Cost_y, Total Profit_y]
# Index: []
#
# [0 rows x 27 columns]

# %%
new_df.shape
# Out:
# (0, 27)

# %%
r1_df.shape
# Out:
# (5000, 14)

# %%
r2_df.shape
# Out:
# (1000, 14)

# %%
emp = pd.read_csv("C:/Users/avina/Desktop/csv/emp.csv")

# %%
emp
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 11996    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 11997    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 11998    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 11999    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 12000    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
fine = pd.read_csv("C:/Users/avina/Desktop/csv/fine.csv")

# %%
fine
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0       BDCQ.SF1AA2CA  2016.06    1116.386         NaN      F  Dollars
# 1       BDCQ.SF1AA2CA  2016.09    1070.874         NaN      F  Dollars
# 2       BDCQ.SF1AA2CA  2016.12    1054.408         NaN      F  Dollars
# 3       BDCQ.SF1AA2CA  2017.03    1010.665         NaN      F  Dollars
# 4       BDCQ.SF1AA2CA  2017.06    1233.700         NaN      F  Dollars
# ...               ...      ...         ...         ...    ...      ...
# 1827    BDCQ.SF8RS2CA  2019.09     157.562         NaN      F  Dollars
# 1828    BDCQ.SF8RS2CA  2019.12     106.326         NaN      F  Dollars
# 1829    BDCQ.SF8RS2CA  2020.03     141.986         NaN      F  Dollars
# 1830    BDCQ.SF8RS2CA  2020.06      -5.260         NaN      F  Dollars
# 1831    BDCQ.SF8RS2CA  2020.09      73.572         NaN      F  Dollars
#
#       Magnitude                         Subject  \
# 0             6  Business Data Collection - BDC
# ...

# %%
index = pd.read_csv("C:/Users/avina/Desktop/csv/index.csv")
# Out:
# C:\Users\avina\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
index
# Out:
#       Series_reference   Period  Data_value STATUS  UNITS  \
# 0           CEPQ.S2371  1996.12       899.0  FINAL  Index
# 1           CEPQ.S2371  1997.03       884.0  FINAL  Index
# 2           CEPQ.S2371  1997.06       925.0  FINAL  Index
# 3           CEPQ.S2371  1997.09       932.0  FINAL  Index
# 4           CEPQ.S2371  1997.12       929.0  FINAL  Index
# ...                ...      ...         ...    ...    ...
# 68077   PPIQ.SQURS2110  2019.09      1264.0  FINAL  Index
# 68078   PPIQ.SQURS2110  2019.12      1279.0  FINAL  Index
# 68079   PPIQ.SQURS2110  2020.03      1304.0  FINAL  Index
# 68080   PPIQ.SQURS2110  2020.06      1347.0  FINAL  Index
# 68081   PPIQ.SQURS2110  2020.09      1315.0  FINAL  Index
#
#                                Subject  \
# 0      Capital Goods Price Index - CEP
# 1      Capital Goods Price Index - CEP
# 2      Capital Goods Price Index - CEP
# 3      Capital Goods Price Index - CEP
# 4      Capital Goods Price Index - CEP
# ...

# %% [markdown]
# ### Join try how left / right / outer

# %%
df1 = pd.DataFrame({'Fruit':['Apple','Orange','Mangoe','Kiwi'],
       'Quantity':['14','12','20','8'],
       'Box':['A','B','C','D']})
df2 = pd.DataFrame({'Fruit':['Gauva','Cherries','Pineaple'],
       'Quantity':['13','22','10'],
       'Box':['E','F','G']})

# %%
df1
# Out:
#     Fruit Quantity Box
# 0   Apple       14   A
# 1  Orange       12   B
# 2  Mangoe       20   C
# 3    Kiwi        8   D

# %%
df2
# Out:
#       Fruit Quantity Box
# 0     Gauva       13   E
# 1  Cherries       22   F
# 2  Pineaple       10   G

# %%
pd.concat([df1,df2], axis = 0)
# Out:
#       Fruit Quantity Box
# 0     Apple       14   A
# 1    Orange       12   B
# 2    Mangoe       20   C
# 3      Kiwi        8   D
# 0     Gauva       13   E
# 1  Cherries       22   F
# 2  Pineaple       10   G

# %%
df1.append(df2)
# Out:
#       Fruit Quantity Box
# 0     Apple       14   A
# 1    Orange       12   B
# 2    Mangoe       20   C
# 3      Kiwi        8   D
# 0     Gauva       13   E
# 1  Cherries       22   F
# 2  Pineaple       10   G

# %%
pd.concat([df1,df2], axis = 1)
# Out:
#     Fruit Quantity Box     Fruit Quantity  Box
# 0   Apple       14   A     Gauva       13    E
# 1  Orange       12   B  Cherries       22    F
# 2  Mangoe       20   C  Pineaple       10    G
# 3    Kiwi        8   D       NaN      NaN  NaN

# %%
pd.concat([df1,df2], axis = 1)
# Out:
#     Fruit Quantity Box     Fruit Quantity  Box
# 0   Apple       14   A     Gauva       13    E
# 1  Orange       12   B  Cherries       22    F
# 2  Mangoe       20   C  Pineaple       10    G
# 3    Kiwi        8   D       NaN      NaN  NaN

# %%
df3 = df1+df2

# %%
df3
# Out:
#             Fruit Quantity  Box
# 0      AppleGauva     1413   AE
# 1  OrangeCherries     1222   BF
# 2  MangoePineaple     2010   CG
# 3             NaN      NaN  NaN
